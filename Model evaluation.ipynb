# %% [markdown]
# #**Model evaluation**
#
# There are 1112 models available to download using the timm package. And many more available on github, huggingface or other sources. In some cases the performance metrics of the models are not properly declared by the repositiories (I found a bug in one of the papers when I was writing this notebook).
#
# The goal of this notebook is to provide a place to evaluate models. This should help to select models that are similar to each other in terms of computational performance but with different architectures.

# %% [markdown]
# ## Metrics

# %% [markdown]
# There are several metrics that are compared:
#
# **FLOPs** which stands for Floating Point Operations Per Second, is a measure how many floating point operations are done.
#
# **MACs** which stands for Multiply-ACcumulate operations, is a measure how many multiply and accumulates we perform.
#
# Both of therse are used to evaluate neural networks. Both aren't perfect but allow to predict the computational requirements.

# %% [markdown]
# **parameters count** is a metric that everyone knows well. Unfortunetly there is no easy correlation between the count of parameters and its accuracy. There is however a correlation with inference time.

# %% [markdown]
# **inference time** is the time it takes the model to predict the outcome. There are two methods covered. The first one is the inference using the PyTorch. The second one is the ONNX inference.

# %% [markdown]
# **train time** is the last metric but due to the nature of this notebook (CPU execution) it is not evaluated here fully.

# %% [markdown]
# # Installation
#
# First step is to install the necessary packages and do the basic imports.
# We install the following:
# - **calflops**, a package to evaluate the FLOPs, MACs and parameter counts.
# - **nn-meter**, a tool to estimate the ONNX model performance on a mobile device (Microsoft repo)
# - **onnx** and **onnxscript**, required to build the ONNX models
#
# When all are installed we can proceed further to evaluate the models.

# %%
# !pip install calflops -q

# %%
#!pip install timm -q

# use github timm for mobilenet v4
# !pip install git+https://github.com/rwightman/pytorch-image-models.git
# Out:
# Collecting git+https://github.com/rwightman/pytorch-image-models.git
#   Cloning https://github.com/rwightman/pytorch-image-models.git to /tmp/pip-req-build-xxkvli5n
#   Running command git clone --filter=blob:none --quiet https://github.com/rwightman/pytorch-image-models.git /tmp/pip-req-build-xxkvli5n
#   Resolved https://github.com/rwightman/pytorch-image-models.git to commit 20fe56bd9072af61d9f5404ce8b08e24ff10a807
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (from timm==1.0.8.dev0) (2.3.0+cu121)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.10/dist-packages (from timm==1.0.8.dev0) (0.18.0+cu121)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from timm==1.0.8.dev0) (6.0.1)
# Requirement already satisfied: huggingface_hub in /usr/local/lib/python3.10/dist-packages (from timm==1.0.8.dev0) (0.23.4)
# Requirement already satisfied: safetensors in /usr/local/lib/python3.10/dist-packages (from timm==1.0.8.dev0) (0.4.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface_hub->timm==1.0.8.dev0) (3.15.4)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub->timm==1.0.8.dev0) (2023.6.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub->timm==1.0.8.dev0) (24.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface_hub->timm==1.0.8.dev0) (2.31.0)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub->timm==1.0.8.dev0) (4.66.4)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub->timm==1.0.8.dev0) (4.12.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch->timm==1.0.8.dev0) (1.12.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch->timm==1.0.8.dev0) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch->timm==1.0.8.dev0) (3.1.4)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch->timm==1.0.8.dev0) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch->timm==1.0.8.dev0) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch->timm==1.0.8.dev0) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /usr/local/lib/python3.10/dist-packages (from torch->timm==1.0.8.dev0) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /usr/local/lib/python3.10/dist-packages (from torch->timm==1.0.8.dev0) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /usr/local/lib/python3.10/dist-packages (from torch->timm==1.0.8.dev0) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /usr/local/lib/python3.10/dist-packages (from torch->timm==1.0.8.dev0) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /usr/local/lib/python3.10/dist-packages (from torch->timm==1.0.8.dev0) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /usr/local/lib/python3.10/dist-packages (from torch->timm==1.0.8.dev0) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.20.5 in /usr/local/lib/python3.10/dist-packages (from torch->timm==1.0.8.dev0) (2.20.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch->timm==1.0.8.dev0) (12.1.105)
# Requirement already satisfied: triton==2.3.0 in /usr/local/lib/python3.10/dist-packages (from torch->timm==1.0.8.dev0) (2.3.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.10/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch->timm==1.0.8.dev0) (12.5.82)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from torchvision->timm==1.0.8.dev0) (1.25.2)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.10/dist-packages (from torchvision->timm==1.0.8.dev0) (9.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch->timm==1.0.8.dev0) (2.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface_hub->timm==1.0.8.dev0) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface_hub->timm==1.0.8.dev0) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface_hub->timm==1.0.8.dev0) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface_hub->timm==1.0.8.dev0) (2024.6.2)
# Requirement already satisfied: mpmath<1.4.0,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->torch->timm==1.0.8.dev0) (1.3.0)

# %%
# !pip install pandas -q

# %% [markdown]
# # Evaluate computational metrics

# %% [markdown]
# TIMM package is used as an exclusive source of the models. Model evaluation can be done on a single model at a time. The model name from timm is used as the key. The outcomes are stored (FLOPs) or can be stored (in case of inference for example) in a file (csv).

# %% [markdown]
# ## Helpers
#
# **getModel** function is used to load the models and their shape data.
#
# **LogBook** class is used to instantinate the **log** that contains the experiment data.
#
# WARNING: access to GDrive is required (to store the log).

# %%
# use default 299 size of the DF20 dataset
import timm

def getModel(model_name, input_size=(3, 299, 299)):
  model = timm.create_model(model_name, pretrained=True)
  size = model.pretrained_cfg['input_size']
  if input_size != None:
    # use own input size
    size = input_size
  return model, size

# %%
# open or create a df for the results
import pandas as pd
from pathlib import Path
import math

class LogBook:
  def __init__(self, file_path='model_results.csv'):
    self.file_path = file_path
    if not Path(file_path).exists():
      print('Create file')
      self.df = pd.DataFrame(columns=['model_name', 'input_size', 'flops', 'macs', 'params', 'flops_back', 'macs_back', 'inference_ms', 'train_b32ps'])
      self.df.set_index(['model_name','input_size'], inplace=True)
    else:
      print('Read file')
      self.df = pd.read_csv(file_path)
      self.df.set_index(['model_name','input_size'], inplace=True)
    #print(self.df.head())

  def save(self):
    self.df.to_csv(self.file_path, index=True)
    print('Saved!')

  def new_entry(self, model_name, input_size):
    print("New entry 2")
    print(len(self.df.columns))
    new_data = {'flops': math.nan, 'macs': math.nan, 'params': math.nan,
                'flops_back': math.nan, 'macs_back': math.nan,
                'inference_ms': math.nan, 'train_sps': math.nan}
    self.df.loc[(model_name, input_size)] = new_data
    print(self.df.head())
    self.save()

  def add(self, model_name, input_size, flops, macs, params, flops_back, macs_back, inference_torch_ms):
    self.df.loc[model_name, input_size] = [flops, macs, params, flops_back, macs_back, inference_torch_ms]
    self.save()

  def add(self, model_name, input_size, **kwargs):
    for key, value in kwargs.items():
        self.df.at[(model_name, input_size), key] = value
    self.save()
    self.df.head()

# %%
# mount GDrive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# make the log
log = LogBook(file_path='/content/drive/MyDrive/Fungi/model_results.csv')
#log.add('bruum22', 299, flops=27.233, params=14.2)
#log.df.head()
# Out:
# Create file

# %% [markdown]
# # Experiment setup

# %% [markdown]
# Results from all the runs are stored in the CSV file. The file is conviniently located on the GDrive. The keys to the table are **model name** and **input size** (only a single edge, in pix).
#
# The following parameters are recorded:
# - GFLOPs
# - GMACs
# - MParams
# - GFLOPs with backprop
# - GMACs with backprop
# - inference time in ms using CPU - for a single image
# - training time using GPU (L4 on Colab) - measure the average train time on batch size 32

# %%
# preview experiments
log.df.sort_index(level=[0,1], ascending=True).head()
#log.df.sort_index(level=[1,0], ascending=True).head()
# Out:
#                                    flops  macs params flops_back macs_back  \
# model_name              input_size
# efficientnet_b0.ra_in1k 224         0.79  0.39   5.29       2.37      1.16
#                         299          1.5  0.73   5.29       4.49      2.19
# mobilenetv2_100.ra_in1k 224         0.61   0.3    3.5       1.84       0.9
#                         299         1.15  0.56    3.5       3.46      1.69
#
#                                    inference_ms train_b32ps
# model_name              input_size
# efficientnet_b0.ra_in1k 224               22.93       11.39
#                         299               31.29        5.67
# mobilenetv2_100.ra_in1k 224               17.29       15.69
#                         299               24.05        7.56

# %% [markdown]
# Experiment is set up by passing the name of the model and its input shape. Both of these values are keys in the dataframe. The log entries are made automatically. Remember there can be only one entry for the keys (name, shape).

# %%
# place the model name here...
#model_name = "efficientnet_b0.ra_in1k"
model_name = "mobilenetv2_100.ra_in1k"

# define the size of the input as a single number (HxW where H=W eg. 299)
# if = None the model input size is used. Not all models support custom input size.
input_image_size = (3, 299, 299)  # eg. (3, 299, 299)

# make a new entry

# %% [markdown]
# # Computation cost tests
#
# This section calculates the FLOPs, MACs and MParams for the model.

# %% [markdown]
# The computational cost is calculated using the calflops package. First for just the forward pass and in the next step for the backpropagation.

# %%
import timm
from calflops import calculate_flops

# %%
batch_size = 1

model, input_shape = getModel(model_name, input_image_size)
input_shape = (batch_size, *input_shape)    # include batch size (picture count)
#print(input_shape)

flops, macs, params = calculate_flops(model=model,
                                      input_shape=input_shape,
                                      output_as_string=False,
                                      include_backPropagation=False)

flops = round(flops/10**9,2)   # convert to GFLOPs
macs = round(macs/10**9,2)     # convert to GMACs
params = round(params/10**6,2) # convert to millions

print(f"FLOPs: {flops}, MACs: {macs}, MParams: {params}")
log.add(model_name, input_shape[-1], flops=flops, macs=macs, params=params)

flops, macs, params = calculate_flops(model=model,
                                      input_shape=input_shape,
                                      output_as_string=False,
                                      include_backPropagation=True)

flops = round(flops/10**9,2)   # convert to GFLOPs
macs = round(macs/10**9,2)     # convert to GMACs
params = round(params/10**6,2) # convert to millions

print(f"+backprop FLOPs: {flops}, MACs: {macs}, MParams: {params}")
log.add(model_name, input_shape[-1], flops_back=flops, macs_back=macs)
# Out:
# ------------------------------------- Calculate Flops Results -------------------------------------
# Notations:
# number of parameters (Params), number of multiply-accumulate operations(MACs),
# number of floating-point operations (FLOPs), floating-point operations per second (FLOPS),
# fwd FLOPs (model forward propagation FLOPs), bwd FLOPs (model backward propagation FLOPs),
# default model backpropagation takes 2.00 times as much computation as forward propagation.
#
# Total Training Params:                                                  3.5 M
# fwd MACs:                                                               564.41 MMACs
# fwd FLOPs:                                                              1.15 GFLOPS
# fwd+bwd MACs:                                                           1.69 GMACs
# fwd+bwd FLOPs:                                                          3.46 GFLOPS
#
# -------------------------------- Detailed Calculated FLOPs Results --------------------------------
# Each module caculated is listed after its name in the following order:
# params, percentage of total params, MACs, percentage of total MACs, FLOPS, percentage of total FLOPs
#
# Note: 1. A module can have torch.nn.module or torch.nn.functional to compute logits (e.g. CrossEntropyLoss).
#  They are not counted as submodules in calflops and not to be printed out. However they make up the difference between a parent's MACs and the sum of its submodules'.
# 2. Number of floating-point operations is a theoretical estimation, thus FLOPS computed using that could be larger than the maximum system throughput.
#
# EfficientNet(
#   3.5 M = 100% Params, 564.41 MMACs = 100% MACs, 1.15 GFLOPS = 100% FLOPs
#   (conv_stem): Conv2d(864 = 0.02% Params, 19.44 MMACs = 3.44% MACs, 38.88 MFLOPS = 3.37% FLOPs, 3, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#   (bn1): BatchNormAct2d(
#     64 = 0% Params, 0 MACs = 0% MACs, 1.44 MFLOPS = 0.12% FLOPs, 32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#     (drop): Identity(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs)
#     (act): ReLU6(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs, inplace=True)
#   )
#   (blocks): Sequential(
#     1.81 M = 51.66% Params, 502.73 MMACs = 89.07% MACs, 1.03 GFLOPS = 89.15% FLOPs
#     (0): Sequential(
#       896 = 0.03% Params, 18 MMACs = 3.19% MACs, 38.16 MFLOPS = 3.31% FLOPs
#       (0): DepthwiseSeparableConv(
#         896 = 0.03% Params, 18 MMACs = 3.19% MACs, 38.16 MFLOPS = 3.31% FLOPs
#         (conv_dw): Conv2d(288 = 0.01% Params, 6.48 MMACs = 1.15% MACs, 12.96 MFLOPS = 1.12% FLOPs, 32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#         (bn1): BatchNormAct2d(
#           64 = 0% Params, 0 MACs = 0% MACs, 1.44 MFLOPS = 0.12% FLOPs, 32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs)
#           (act): ReLU6(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs, inplace=True)
#         )
#         (aa): Identity(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs)
#         (se): Identity(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs)
#         (conv_pw): Conv2d(512 = 0.01% Params, 11.52 MMACs = 2.04% MACs, 23.04 MFLOPS = 2% FLOPs, 32, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn2): BatchNormAct2d(
#           32 = 0% Params, 0 MACs = 0% MACs, 720 KFLOPS = 0.06% FLOPs, 16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs)
#           (act): Identity(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs)
#         )
#         (drop_path): Identity(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs)
#       )
#     )
#     (1): Sequential(
#       13.97 K = 0.4% Params, 98.55 MMACs = 17.46% MACs, 206.28 MFLOPS = 17.89% FLOPs
#       (0): InvertedResidual(
#         5.14 K = 0.15% Params, 52.38 MMACs = 9.28% MACs, 110.43 MFLOPS = 9.57% FLOPs
#         (conv_pw): Conv2d(1.54 K = 0.04% Params, 34.56 MMACs = 6.12% MACs, 69.12 MFLOPS = 5.99% FLOPs, 16, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNormAct2d(
#           192 = 0.01% Params, 0 MACs = 0% MACs, 4.32 MFLOPS = 0.37% FLOPs, 96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs)
#           (act): ReLU6(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs, inplace=True)
#         )
#         (conv_dw): Conv2d(864 = 0.02% Params, 4.86 MMACs = 0.86% MACs, 9.72 MFLOPS = 0.84% FLOPs, 96, 96, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=96, bias=False)
#         (bn2): BatchNormAct2d(
#           192 = 0.01% Params, 0 MACs = 0% MACs, 1.08 MFLOPS = 0.09% FLOPs, 96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs)
#           (act): ReLU6(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs, inplace=True)
#         )
#         (aa): Identity(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs)
#         (se): Identity(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs)
#         (conv_pwl): Conv2d(2.3 K = 0.07% Params, 12.96 MMACs = 2.3% MACs, 25.92 MFLOPS = 2.25% FLOPs, 96, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNormAct2d(
#           48 = 0% Params, 0 MACs = 0% MACs, 270 KFLOPS = 0.02% FLOPs, 24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs)
#           (act): Identity(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs)
#         )
#         (drop_path): Identity(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs)
#       )
#       (1): InvertedResidual(
#         8.83 K = 0.25% Params, 46.17 MMACs = 8.18% MACs, 95.85 MFLOPS = 8.31% FLOPs
#         (conv_pw): Conv2d(3.46 K = 0.1% Params, 19.44 MMACs = 3.44% MACs, 38.88 MFLOPS = 3.37% FLOPs, 24, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNormAct2d(
#           288 = 0.01% Params, 0 MACs = 0% MACs, 1.62 MFLOPS = 0.14% FLOPs, 144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs)
#           (act): ReLU6(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs, inplace=True)
#         )
#         (conv_dw): Conv2d(1.3 K = 0.04% Params, 7.29 MMACs = 1.29% MACs, 14.58 MFLOPS = 1.26% FLOPs, 144, 144, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=144, bias=False)
#         (bn2): BatchNormAct2d(
#           288 = 0.01% Params, 0 MACs = 0% MACs, 1.62 MFLOPS = 0.14% FLOPs, 144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs)
#           (act): ReLU6(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs, inplace=True)
#         )
#         (aa): Identity(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs)
#         (se): Identity(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs)
#         (conv_pwl): Conv2d(3.46 K = 0.1% Params, 19.44 MMACs = 3.44% MACs, 38.88 MFLOPS = 3.37% FLOPs, 144, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNormAct2d(
#           48 = 0% Params, 0 MACs = 0% MACs, 270 KFLOPS = 0.02% FLOPs, 24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs)
#           (act): Identity(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs)
#         )
#         (drop_path): Identity(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs)
#       )
#     )
#     (2): Sequential(
#       39.7 K = 1.13% Params, 68.44 MMACs = 12.13% MACs, 141.42 MFLOPS = 12.26% FLOPs
#       (0): InvertedResidual(
#         10 K = 0.29% Params, 27.97 MMACs = 4.95% MACs, 58.06 MFLOPS = 5.03% FLOPs
#         (conv_pw): Conv2d(3.46 K = 0.1% Params, 19.44 MMACs = 3.44% MACs, 38.88 MFLOPS = 3.37% FLOPs, 24, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNormAct2d(
#           288 = 0.01% Params, 0 MACs = 0% MACs, 1.62 MFLOPS = 0.14% FLOPs, 144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs)
#           (act): ReLU6(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs, inplace=True)
#         )
#         (conv_dw): Conv2d(1.3 K = 0.04% Params, 1.87 MMACs = 0.33% MACs, 3.74 MFLOPS = 0.32% FLOPs, 144, 144, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=144, bias=False)
#         (bn2): BatchNormAct2d(
#           288 = 0.01% Params, 0 MACs = 0% MACs, 415.87 KFLOPS = 0.04% FLOPs, 144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs)
#           (act): ReLU6(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs, inplace=True)
#         )
#         (aa): Identity(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs)
#         (se): Identity(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs)
#         (conv_pwl): Conv2d(4.61 K = 0.13% Params, 6.65 MMACs = 1.18% MACs, 13.31 MFLOPS = 1.15% FLOPs, 144, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNormAct2d(
#           64 = 0% Params, 0 MACs = 0% MACs, 92.42 KFLOPS = 0.01% FLOPs, 32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs)
#           (act): Identity(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs)
#         )
#         (drop_path): Identity(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs)
#       )
#       (1): InvertedResidual(
#         14.85 K = 0.42% Params, 20.24 MMACs = 3.59% MACs, 41.68 MFLOPS = 3.61% FLOPs
#         (conv_pw): Conv2d(6.14 K = 0.18% Params, 8.87 MMACs = 1.57% MACs, 17.74 MFLOPS = 1.54% FLOPs, 32, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNormAct2d(
#           384 = 0.01% Params, 0 MACs = 0% MACs, 554.5 KFLOPS = 0.05% FLOPs, 192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs)
#           (act): ReLU6(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs, inplace=True)
#         )
#         (conv_dw): Conv2d(1.73 K = 0.05% Params, 2.5 MMACs = 0.44% MACs, 4.99 MFLOPS = 0.43% FLOPs, 192, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=192, bias=False)
#         (bn2): BatchNormAct2d(
#           384 = 0.01% Params, 0 MACs = 0% MACs, 554.5 KFLOPS = 0.05% FLOPs, 192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs)
#           (act): ReLU6(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs, inplace=True)
#         )
#         (aa): Identity(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs)
#         (se): Identity(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs)
#         (conv_pwl): Conv2d(6.14 K = 0.18% Params, 8.87 MMACs = 1.57% MACs, 17.74 MFLOPS = 1.54% FLOPs, 192, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNormAct2d(
#           64 = 0% Params, 0 MACs = 0% MACs, 92.42 KFLOPS = 0.01% FLOPs, 32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs)
#           (act): Identity(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs)
#         )
#         (drop_path): Identity(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs)
#       )
#       (2): InvertedResidual(
#         14.85 K = 0.42% Params, 20.24 MMACs = 3.59% MACs, 41.68 MFLOPS = 3.61% FLOPs
#         (conv_pw): Conv2d(6.14 K = 0.18% Params, 8.87 MMACs = 1.57% MACs, 17.74 MFLOPS = 1.54% FLOPs, 32, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNormAct2d(
#           384 = 0.01% Params, 0 MACs = 0% MACs, 554.5 KFLOPS = 0.05% FLOPs, 192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs)
#           (act): ReLU6(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs, inplace=True)
#         )
#         (conv_dw): Conv2d(1.73 K = 0.05% Params, 2.5 MMACs = 0.44% MACs, 4.99 MFLOPS = 0.43% FLOPs, 192, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=192, bias=False)
#         (bn2): BatchNormAct2d(
#           384 = 0.01% Params, 0 MACs = 0% MACs, 554.5 KFLOPS = 0.05% FLOPs, 192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs)
#           (act): ReLU6(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs, inplace=True)
#         )
#         (aa): Identity(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs)
#         (se): Identity(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs)
#         (conv_pwl): Conv2d(6.14 K = 0.18% Params, 8.87 MMACs = 1.57% MACs, 17.74 MFLOPS = 1.54% FLOPs, 192, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNormAct2d(
#           64 = 0% Params, 0 MACs = 0% MACs, 92.42 KFLOPS = 0.01% FLOPs, 32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs)
#           (act): Identity(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs)
#         )
#         (drop_path): Identity(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs)
#       )
#     )
#     (3): Sequential(
#       183.87 K = 5.25% Params, 70.91 MMACs = 12.56% MACs, 144.35 MFLOPS = 12.52% FLOPs
#       (0): InvertedResidual(
#         21.06 K = 0.6% Params, 13.93 MMACs = 2.47% MACs, 28.6 MFLOPS = 2.48% FLOPs
#         (conv_pw): Conv2d(6.14 K = 0.18% Params, 8.87 MMACs = 1.57% MACs, 17.74 MFLOPS = 1.54% FLOPs, 32, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNormAct2d(
#           384 = 0.01% Params, 0 MACs = 0% MACs, 554.5 KFLOPS = 0.05% FLOPs, 192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs)
#           (act): ReLU6(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs, inplace=True)
#         )
#         (conv_dw): Conv2d(1.73 K = 0.05% Params, 623.81 KMACs = 0.11% MACs, 1.25 MFLOPS = 0.11% FLOPs, 192, 192, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=192, bias=False)
#         (bn2): BatchNormAct2d(
#           384 = 0.01% Params, 0 MACs = 0% MACs, 138.62 KFLOPS = 0.01% FLOPs, 192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs)
#           (act): ReLU6(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs, inplace=True)
#         )
#         (aa): Identity(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs)
#         (se): Identity(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs)
#         (conv_pwl): Conv2d(12.29 K = 0.35% Params, 4.44 MMACs = 0.79% MACs, 8.87 MFLOPS = 0.77% FLOPs, 192, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNormAct2d(
#           128 = 0% Params, 0 MACs = 0% MACs, 46.21 KFLOPS = 0% FLOPs, 64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs)
#           (act): Identity(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs)
#         )
#         (drop_path): Identity(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs)
#       )
#       (1): InvertedResidual(
#         54.27 K = 1.55% Params, 18.99 MMACs = 3.36% MACs, 38.58 MFLOPS = 3.35% FLOPs
#         (conv_pw): Conv2d(24.58 K = 0.7% Params, 8.87 MMACs = 1.57% MACs, 17.74 MFLOPS = 1.54% FLOPs, 64, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNormAct2d(
#           768 = 0.02% Params, 0 MACs = 0% MACs, 277.25 KFLOPS = 0.02% FLOPs, 384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs)
#           (act): ReLU6(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs, inplace=True)
#         )
#         (conv_dw): Conv2d(3.46 K = 0.1% Params, 1.25 MMACs = 0.22% MACs, 2.5 MFLOPS = 0.22% FLOPs, 384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=384, bias=False)
#         (bn2): BatchNormAct2d(
#           768 = 0.02% Params, 0 MACs = 0% MACs, 277.25 KFLOPS = 0.02% FLOPs, 384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs)
#           (act): ReLU6(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs, inplace=True)
#         )
#         (aa): Identity(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs)
#         (se): Identity(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs)
#         (conv_pwl): Conv2d(24.58 K = 0.7% Params, 8.87 MMACs = 1.57% MACs, 17.74 MFLOPS = 1.54% FLOPs, 384, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNormAct2d(
#           128 = 0% Params, 0 MACs = 0% MACs, 46.21 KFLOPS = 0% FLOPs, 64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs)
#           (act): Identity(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs)
#         )
#         (drop_path): Identity(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs)
#       )
#       (2): InvertedResidual(
#         54.27 K = 1.55% Params, 18.99 MMACs = 3.36% MACs, 38.58 MFLOPS = 3.35% FLOPs
#         (conv_pw): Conv2d(24.58 K = 0.7% Params, 8.87 MMACs = 1.57% MACs, 17.74 MFLOPS = 1.54% FLOPs, 64, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNormAct2d(
#           768 = 0.02% Params, 0 MACs = 0% MACs, 277.25 KFLOPS = 0.02% FLOPs, 384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs)
#           (act): ReLU6(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs, inplace=True)
#         )
#         (conv_dw): Conv2d(3.46 K = 0.1% Params, 1.25 MMACs = 0.22% MACs, 2.5 MFLOPS = 0.22% FLOPs, 384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=384, bias=False)
#         (bn2): BatchNormAct2d(
#           768 = 0.02% Params, 0 MACs = 0% MACs, 277.25 KFLOPS = 0.02% FLOPs, 384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs)
#           (act): ReLU6(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs, inplace=True)
#         )
#         (aa): Identity(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs)
#         (se): Identity(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs)
#         (conv_pwl): Conv2d(24.58 K = 0.7% Params, 8.87 MMACs = 1.57% MACs, 17.74 MFLOPS = 1.54% FLOPs, 384, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNormAct2d(
#           128 = 0% Params, 0 MACs = 0% MACs, 46.21 KFLOPS = 0% FLOPs, 64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs)
#           (act): Identity(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs)
#         )
#         (drop_path): Identity(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs)
#       )
#       (3): InvertedResidual(
#         54.27 K = 1.55% Params, 18.99 MMACs = 3.36% MACs, 38.58 MFLOPS = 3.35% FLOPs
#         (conv_pw): Conv2d(24.58 K = 0.7% Params, 8.87 MMACs = 1.57% MACs, 17.74 MFLOPS = 1.54% FLOPs, 64, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNormAct2d(
#           768 = 0.02% Params, 0 MACs = 0% MACs, 277.25 KFLOPS = 0.02% FLOPs, 384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs)
#           (act): ReLU6(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs, inplace=True)
#         )
#         (conv_dw): Conv2d(3.46 K = 0.1% Params, 1.25 MMACs = 0.22% MACs, 2.5 MFLOPS = 0.22% FLOPs, 384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=384, bias=False)
#         (bn2): BatchNormAct2d(
#           768 = 0.02% Params, 0 MACs = 0% MACs, 277.25 KFLOPS = 0.02% FLOPs, 384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs)
#           (act): ReLU6(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs, inplace=True)
#         )
#         (aa): Identity(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs)
#         (se): Identity(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs)
#         (conv_pwl): Conv2d(24.58 K = 0.7% Params, 8.87 MMACs = 1.57% MACs, 17.74 MFLOPS = 1.54% FLOPs, 384, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNormAct2d(
#           128 = 0% Params, 0 MACs = 0% MACs, 46.21 KFLOPS = 0% FLOPs, 64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs)
#           (act): Identity(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs)
#         )
#         (drop_path): Identity(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs)
#       )
#     )
#     (4): Sequential(
#       303.17 K = 8.65% Params, 107.02 MMACs = 18.96% MACs, 216.46 MFLOPS = 18.77% FLOPs
#       (0): InvertedResidual(
#         66.62 K = 1.9% Params, 23.43 MMACs = 4.15% MACs, 47.48 MFLOPS = 4.12% FLOPs
#         (conv_pw): Conv2d(24.58 K = 0.7% Params, 8.87 MMACs = 1.57% MACs, 17.74 MFLOPS = 1.54% FLOPs, 64, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNormAct2d(
#           768 = 0.02% Params, 0 MACs = 0% MACs, 277.25 KFLOPS = 0.02% FLOPs, 384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs)
#           (act): ReLU6(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs, inplace=True)
#         )
#         (conv_dw): Conv2d(3.46 K = 0.1% Params, 1.25 MMACs = 0.22% MACs, 2.5 MFLOPS = 0.22% FLOPs, 384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=384, bias=False)
#         (bn2): BatchNormAct2d(
#           768 = 0.02% Params, 0 MACs = 0% MACs, 277.25 KFLOPS = 0.02% FLOPs, 384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs)
#           (act): ReLU6(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs, inplace=True)
#         )
#         (aa): Identity(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs)
#         (se): Identity(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs)
#         (conv_pwl): Conv2d(36.86 K = 1.05% Params, 13.31 MMACs = 2.36% MACs, 26.62 MFLOPS = 2.31% FLOPs, 384, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNormAct2d(
#           192 = 0.01% Params, 0 MACs = 0% MACs, 69.31 KFLOPS = 0.01% FLOPs, 96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs)
#           (act): Identity(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs)
#         )
#         (drop_path): Identity(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs)
#       )
#       (1): InvertedResidual(
#         118.27 K = 3.37% Params, 41.8 MMACs = 7.41% MACs, 84.49 MFLOPS = 7.33% FLOPs
#         (conv_pw): Conv2d(55.3 K = 1.58% Params, 19.96 MMACs = 3.54% MACs, 39.92 MFLOPS = 3.46% FLOPs, 96, 576, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNormAct2d(
#           1.15 K = 0.03% Params, 0 MACs = 0% MACs, 415.87 KFLOPS = 0.04% FLOPs, 576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs)
#           (act): ReLU6(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs, inplace=True)
#         )
#         (conv_dw): Conv2d(5.18 K = 0.15% Params, 1.87 MMACs = 0.33% MACs, 3.74 MFLOPS = 0.32% FLOPs, 576, 576, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=576, bias=False)
#         (bn2): BatchNormAct2d(
#           1.15 K = 0.03% Params, 0 MACs = 0% MACs, 415.87 KFLOPS = 0.04% FLOPs, 576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs)
#           (act): ReLU6(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs, inplace=True)
#         )
#         (aa): Identity(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs)
#         (se): Identity(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs)
#         (conv_pwl): Conv2d(55.3 K = 1.58% Params, 19.96 MMACs = 3.54% MACs, 39.92 MFLOPS = 3.46% FLOPs, 576, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNormAct2d(
#           192 = 0.01% Params, 0 MACs = 0% MACs, 69.31 KFLOPS = 0.01% FLOPs, 96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs)
#           (act): Identity(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs)
#         )
#         (drop_path): Identity(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs)
#       )
#       (2): InvertedResidual(
#         118.27 K = 3.37% Params, 41.8 MMACs = 7.41% MACs, 84.49 MFLOPS = 7.33% FLOPs
#         (conv_pw): Conv2d(55.3 K = 1.58% Params, 19.96 MMACs = 3.54% MACs, 39.92 MFLOPS = 3.46% FLOPs, 96, 576, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNormAct2d(
#           1.15 K = 0.03% Params, 0 MACs = 0% MACs, 415.87 KFLOPS = 0.04% FLOPs, 576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs)
#           (act): ReLU6(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs, inplace=True)
#         )
#         (conv_dw): Conv2d(5.18 K = 0.15% Params, 1.87 MMACs = 0.33% MACs, 3.74 MFLOPS = 0.32% FLOPs, 576, 576, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=576, bias=False)
#         (bn2): BatchNormAct2d(
#           1.15 K = 0.03% Params, 0 MACs = 0% MACs, 415.87 KFLOPS = 0.04% FLOPs, 576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs)
#           (act): ReLU6(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs, inplace=True)
#         )
#         (aa): Identity(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs)
#         (se): Identity(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs)
#         (conv_pwl): Conv2d(55.3 K = 1.58% Params, 19.96 MMACs = 3.54% MACs, 39.92 MFLOPS = 3.46% FLOPs, 576, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNormAct2d(
#           192 = 0.01% Params, 0 MACs = 0% MACs, 69.31 KFLOPS = 0.01% FLOPs, 96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs)
#           (act): Identity(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs)
#         )
#         (drop_path): Identity(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs)
#       )
#     )
#     (5): Sequential(
#       795.26 K = 22.69% Params, 92.86 MMACs = 16.45% MACs, 187.12 MFLOPS = 16.22% FLOPs
#       (0): InvertedResidual(
#         155.26 K = 4.43% Params, 29.7 MMACs = 5.26% MACs, 59.96 MFLOPS = 5.2% FLOPs
#         (conv_pw): Conv2d(55.3 K = 1.58% Params, 19.96 MMACs = 3.54% MACs, 39.92 MFLOPS = 3.46% FLOPs, 96, 576, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNormAct2d(
#           1.15 K = 0.03% Params, 0 MACs = 0% MACs, 415.87 KFLOPS = 0.04% FLOPs, 576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs)
#           (act): ReLU6(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs, inplace=True)
#         )
#         (conv_dw): Conv2d(5.18 K = 0.15% Params, 518.4 KMACs = 0.09% MACs, 1.04 MFLOPS = 0.09% FLOPs, 576, 576, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=576, bias=False)
#         (bn2): BatchNormAct2d(
#           1.15 K = 0.03% Params, 0 MACs = 0% MACs, 115.2 KFLOPS = 0.01% FLOPs, 576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs)
#           (act): ReLU6(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs, inplace=True)
#         )
#         (aa): Identity(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs)
#         (se): Identity(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs)
#         (conv_pwl): Conv2d(92.16 K = 2.63% Params, 9.22 MMACs = 1.63% MACs, 18.43 MFLOPS = 1.6% FLOPs, 576, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNormAct2d(
#           320 = 0.01% Params, 0 MACs = 0% MACs, 32 KFLOPS = 0% FLOPs, 160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs)
#           (act): Identity(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs)
#         )
#         (drop_path): Identity(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs)
#       )
#       (1): InvertedResidual(
#         320 K = 9.13% Params, 31.58 MMACs = 5.6% MACs, 63.58 MFLOPS = 5.51% FLOPs
#         (conv_pw): Conv2d(153.6 K = 4.38% Params, 15.36 MMACs = 2.72% MACs, 30.72 MFLOPS = 2.66% FLOPs, 160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNormAct2d(
#           1.92 K = 0.05% Params, 0 MACs = 0% MACs, 192 KFLOPS = 0.02% FLOPs, 960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs)
#           (act): ReLU6(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs, inplace=True)
#         )
#         (conv_dw): Conv2d(8.64 K = 0.25% Params, 864 KMACs = 0.15% MACs, 1.73 MFLOPS = 0.15% FLOPs, 960, 960, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=960, bias=False)
#         (bn2): BatchNormAct2d(
#           1.92 K = 0.05% Params, 0 MACs = 0% MACs, 192 KFLOPS = 0.02% FLOPs, 960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs)
#           (act): ReLU6(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs, inplace=True)
#         )
#         (aa): Identity(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs)
#         (se): Identity(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs)
#         (conv_pwl): Conv2d(153.6 K = 4.38% Params, 15.36 MMACs = 2.72% MACs, 30.72 MFLOPS = 2.66% FLOPs, 960, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNormAct2d(
#           320 = 0.01% Params, 0 MACs = 0% MACs, 32 KFLOPS = 0% FLOPs, 160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs)
#           (act): Identity(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs)
#         )
#         (drop_path): Identity(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs)
#       )
#       (2): InvertedResidual(
#         320 K = 9.13% Params, 31.58 MMACs = 5.6% MACs, 63.58 MFLOPS = 5.51% FLOPs
#         (conv_pw): Conv2d(153.6 K = 4.38% Params, 15.36 MMACs = 2.72% MACs, 30.72 MFLOPS = 2.66% FLOPs, 160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNormAct2d(
#           1.92 K = 0.05% Params, 0 MACs = 0% MACs, 192 KFLOPS = 0.02% FLOPs, 960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs)
#           (act): ReLU6(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs, inplace=True)
#         )
#         (conv_dw): Conv2d(8.64 K = 0.25% Params, 864 KMACs = 0.15% MACs, 1.73 MFLOPS = 0.15% FLOPs, 960, 960, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=960, bias=False)
#         (bn2): BatchNormAct2d(
#           1.92 K = 0.05% Params, 0 MACs = 0% MACs, 192 KFLOPS = 0.02% FLOPs, 960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs)
#           (act): ReLU6(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs, inplace=True)
#         )
#         (aa): Identity(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs)
#         (se): Identity(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs)
#         (conv_pwl): Conv2d(153.6 K = 4.38% Params, 15.36 MMACs = 2.72% MACs, 30.72 MFLOPS = 2.66% FLOPs, 960, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNormAct2d(
#           320 = 0.01% Params, 0 MACs = 0% MACs, 32 KFLOPS = 0% FLOPs, 160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs)
#           (act): Identity(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs)
#         )
#         (drop_path): Identity(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs)
#       )
#     )
#     (6): Sequential(
#       473.92 K = 13.52% Params, 46.94 MMACs = 8.32% MACs, 94.34 MFLOPS = 8.18% FLOPs
#       (0): InvertedResidual(
#         473.92 K = 13.52% Params, 46.94 MMACs = 8.32% MACs, 94.34 MFLOPS = 8.18% FLOPs
#         (conv_pw): Conv2d(153.6 K = 4.38% Params, 15.36 MMACs = 2.72% MACs, 30.72 MFLOPS = 2.66% FLOPs, 160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNormAct2d(
#           1.92 K = 0.05% Params, 0 MACs = 0% MACs, 192 KFLOPS = 0.02% FLOPs, 960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs)
#           (act): ReLU6(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs, inplace=True)
#         )
#         (conv_dw): Conv2d(8.64 K = 0.25% Params, 864 KMACs = 0.15% MACs, 1.73 MFLOPS = 0.15% FLOPs, 960, 960, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=960, bias=False)
#         (bn2): BatchNormAct2d(
#           1.92 K = 0.05% Params, 0 MACs = 0% MACs, 192 KFLOPS = 0.02% FLOPs, 960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs)
#           (act): ReLU6(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs, inplace=True)
#         )
#         (aa): Identity(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs)
#         (se): Identity(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs)
#         (conv_pwl): Conv2d(307.2 K = 8.76% Params, 30.72 MMACs = 5.44% MACs, 61.44 MFLOPS = 5.33% FLOPs, 960, 320, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNormAct2d(
#           640 = 0.02% Params, 0 MACs = 0% MACs, 64 KFLOPS = 0.01% FLOPs, 320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs)
#           (act): Identity(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs)
#         )
#         (drop_path): Identity(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs)
#       )
#     )
#   )
#   (conv_head): Conv2d(409.6 K = 11.69% Params, 40.96 MMACs = 7.26% MACs, 81.92 MFLOPS = 7.1% FLOPs, 320, 1280, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (bn2): BatchNormAct2d(
#     2.56 K = 0.07% Params, 0 MACs = 0% MACs, 256 KFLOPS = 0.02% FLOPs, 1280, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#     (drop): Identity(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs)
#     (act): ReLU6(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs, inplace=True)
#   )
#   (global_pool): SelectAdaptivePool2d(pool_type=avg, flatten=Flatten(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs, start_dim=1, end_dim=-1))
#   (classifier): Linear(1.28 M = 36.55% Params, 1.28 MMACs = 0.23% MACs, 2.56 MFLOPS = 0.22% FLOPs, in_features=1280, out_features=1000, bias=True)
# )
# ---------------------------------------------------------------------------------------------------
# FLOPs: 1.15, MACs: 0.56, MParams: 3.5
# Saved!
#
# ------------------------------------- Calculate Flops Results -------------------------------------
# Notations:
# number of parameters (Params), number of multiply-accumulate operations(MACs),
# number of floating-point operations (FLOPs), floating-point operations per second (FLOPS),
# fwd FLOPs (model forward propagation FLOPs), bwd FLOPs (model backward propagation FLOPs),
# default model backpropagation takes 2.00 times as much computation as forward propagation.
#
# Total Training Params:                                                  3.5 M
# fwd MACs:                                                               564.41 MMACs
# fwd FLOPs:                                                              1.15 GFLOPS
# fwd+bwd MACs:                                                           1.69 GMACs
# fwd+bwd FLOPs:                                                          3.46 GFLOPS
#
# -------------------------------- Detailed Calculated FLOPs Results --------------------------------
# Each module caculated is listed after its name in the following order:
# params, percentage of total params, MACs, percentage of total MACs, FLOPS, percentage of total FLOPs
#
# Note: 1. A module can have torch.nn.module or torch.nn.functional to compute logits (e.g. CrossEntropyLoss).
#  They are not counted as submodules in calflops and not to be printed out. However they make up the difference between a parent's MACs and the sum of its submodules'.
# 2. Number of floating-point operations is a theoretical estimation, thus FLOPS computed using that could be larger than the maximum system throughput.
#
# EfficientNet(
#   3.5 M = 100% Params, 564.41 MMACs = 100% MACs, 1.15 GFLOPS = 100% FLOPs
#   (conv_stem): Conv2d(864 = 0.02% Params, 19.44 MMACs = 3.44% MACs, 38.88 MFLOPS = 3.37% FLOPs, 3, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#   (bn1): BatchNormAct2d(
#     64 = 0% Params, 0 MACs = 0% MACs, 1.44 MFLOPS = 0.12% FLOPs, 32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#     (drop): Identity(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs)
#     (act): ReLU6(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs, inplace=True)
#   )
#   (blocks): Sequential(
#     1.81 M = 51.66% Params, 502.73 MMACs = 89.07% MACs, 1.03 GFLOPS = 89.15% FLOPs
#     (0): Sequential(
#       896 = 0.03% Params, 18 MMACs = 3.19% MACs, 38.16 MFLOPS = 3.31% FLOPs
#       (0): DepthwiseSeparableConv(
#         896 = 0.03% Params, 18 MMACs = 3.19% MACs, 38.16 MFLOPS = 3.31% FLOPs
#         (conv_dw): Conv2d(288 = 0.01% Params, 6.48 MMACs = 1.15% MACs, 12.96 MFLOPS = 1.12% FLOPs, 32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#         (bn1): BatchNormAct2d(
#           64 = 0% Params, 0 MACs = 0% MACs, 1.44 MFLOPS = 0.12% FLOPs, 32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs)
#           (act): ReLU6(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs, inplace=True)
#         )
#         (aa): Identity(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs)
#         (se): Identity(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs)
#         (conv_pw): Conv2d(512 = 0.01% Params, 11.52 MMACs = 2.04% MACs, 23.04 MFLOPS = 2% FLOPs, 32, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn2): BatchNormAct2d(
#           32 = 0% Params, 0 MACs = 0% MACs, 720 KFLOPS = 0.06% FLOPs, 16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs)
#           (act): Identity(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs)
#         )
#         (drop_path): Identity(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs)
#       )
#     )
#     (1): Sequential(
#       13.97 K = 0.4% Params, 98.55 MMACs = 17.46% MACs, 206.28 MFLOPS = 17.89% FLOPs
#       (0): InvertedResidual(
#         5.14 K = 0.15% Params, 52.38 MMACs = 9.28% MACs, 110.43 MFLOPS = 9.57% FLOPs
#         (conv_pw): Conv2d(1.54 K = 0.04% Params, 34.56 MMACs = 6.12% MACs, 69.12 MFLOPS = 5.99% FLOPs, 16, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNormAct2d(
#           192 = 0.01% Params, 0 MACs = 0% MACs, 4.32 MFLOPS = 0.37% FLOPs, 96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs)
#           (act): ReLU6(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs, inplace=True)
#         )
#         (conv_dw): Conv2d(864 = 0.02% Params, 4.86 MMACs = 0.86% MACs, 9.72 MFLOPS = 0.84% FLOPs, 96, 96, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=96, bias=False)
#         (bn2): BatchNormAct2d(
#           192 = 0.01% Params, 0 MACs = 0% MACs, 1.08 MFLOPS = 0.09% FLOPs, 96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs)
#           (act): ReLU6(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs, inplace=True)
#         )
#         (aa): Identity(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs)
#         (se): Identity(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs)
#         (conv_pwl): Conv2d(2.3 K = 0.07% Params, 12.96 MMACs = 2.3% MACs, 25.92 MFLOPS = 2.25% FLOPs, 96, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNormAct2d(
#           48 = 0% Params, 0 MACs = 0% MACs, 270 KFLOPS = 0.02% FLOPs, 24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs)
#           (act): Identity(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs)
#         )
#         (drop_path): Identity(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs)
#       )
#       (1): InvertedResidual(
#         8.83 K = 0.25% Params, 46.17 MMACs = 8.18% MACs, 95.85 MFLOPS = 8.31% FLOPs
#         (conv_pw): Conv2d(3.46 K = 0.1% Params, 19.44 MMACs = 3.44% MACs, 38.88 MFLOPS = 3.37% FLOPs, 24, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNormAct2d(
#           288 = 0.01% Params, 0 MACs = 0% MACs, 1.62 MFLOPS = 0.14% FLOPs, 144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs)
#           (act): ReLU6(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs, inplace=True)
#         )
#         (conv_dw): Conv2d(1.3 K = 0.04% Params, 7.29 MMACs = 1.29% MACs, 14.58 MFLOPS = 1.26% FLOPs, 144, 144, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=144, bias=False)
#         (bn2): BatchNormAct2d(
#           288 = 0.01% Params, 0 MACs = 0% MACs, 1.62 MFLOPS = 0.14% FLOPs, 144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs)
#           (act): ReLU6(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs, inplace=True)
#         )
#         (aa): Identity(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs)
#         (se): Identity(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs)
#         (conv_pwl): Conv2d(3.46 K = 0.1% Params, 19.44 MMACs = 3.44% MACs, 38.88 MFLOPS = 3.37% FLOPs, 144, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNormAct2d(
#           48 = 0% Params, 0 MACs = 0% MACs, 270 KFLOPS = 0.02% FLOPs, 24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs)
#           (act): Identity(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs)
#         )
#         (drop_path): Identity(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs)
#       )
#     )
#     (2): Sequential(
#       39.7 K = 1.13% Params, 68.44 MMACs = 12.13% MACs, 141.42 MFLOPS = 12.26% FLOPs
#       (0): InvertedResidual(
#         10 K = 0.29% Params, 27.97 MMACs = 4.95% MACs, 58.06 MFLOPS = 5.03% FLOPs
#         (conv_pw): Conv2d(3.46 K = 0.1% Params, 19.44 MMACs = 3.44% MACs, 38.88 MFLOPS = 3.37% FLOPs, 24, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNormAct2d(
#           288 = 0.01% Params, 0 MACs = 0% MACs, 1.62 MFLOPS = 0.14% FLOPs, 144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs)
#           (act): ReLU6(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs, inplace=True)
#         )
#         (conv_dw): Conv2d(1.3 K = 0.04% Params, 1.87 MMACs = 0.33% MACs, 3.74 MFLOPS = 0.32% FLOPs, 144, 144, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=144, bias=False)
#         (bn2): BatchNormAct2d(
#           288 = 0.01% Params, 0 MACs = 0% MACs, 415.87 KFLOPS = 0.04% FLOPs, 144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs)
#           (act): ReLU6(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs, inplace=True)
#         )
#         (aa): Identity(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs)
#         (se): Identity(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs)
#         (conv_pwl): Conv2d(4.61 K = 0.13% Params, 6.65 MMACs = 1.18% MACs, 13.31 MFLOPS = 1.15% FLOPs, 144, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNormAct2d(
#           64 = 0% Params, 0 MACs = 0% MACs, 92.42 KFLOPS = 0.01% FLOPs, 32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs)
#           (act): Identity(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs)
#         )
#         (drop_path): Identity(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs)
#       )
#       (1): InvertedResidual(
#         14.85 K = 0.42% Params, 20.24 MMACs = 3.59% MACs, 41.68 MFLOPS = 3.61% FLOPs
#         (conv_pw): Conv2d(6.14 K = 0.18% Params, 8.87 MMACs = 1.57% MACs, 17.74 MFLOPS = 1.54% FLOPs, 32, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNormAct2d(
#           384 = 0.01% Params, 0 MACs = 0% MACs, 554.5 KFLOPS = 0.05% FLOPs, 192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs)
#           (act): ReLU6(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs, inplace=True)
#         )
#         (conv_dw): Conv2d(1.73 K = 0.05% Params, 2.5 MMACs = 0.44% MACs, 4.99 MFLOPS = 0.43% FLOPs, 192, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=192, bias=False)
#         (bn2): BatchNormAct2d(
#           384 = 0.01% Params, 0 MACs = 0% MACs, 554.5 KFLOPS = 0.05% FLOPs, 192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs)
#           (act): ReLU6(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs, inplace=True)
#         )
#         (aa): Identity(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs)
#         (se): Identity(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs)
#         (conv_pwl): Conv2d(6.14 K = 0.18% Params, 8.87 MMACs = 1.57% MACs, 17.74 MFLOPS = 1.54% FLOPs, 192, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNormAct2d(
#           64 = 0% Params, 0 MACs = 0% MACs, 92.42 KFLOPS = 0.01% FLOPs, 32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs)
#           (act): Identity(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs)
#         )
#         (drop_path): Identity(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs)
#       )
#       (2): InvertedResidual(
#         14.85 K = 0.42% Params, 20.24 MMACs = 3.59% MACs, 41.68 MFLOPS = 3.61% FLOPs
#         (conv_pw): Conv2d(6.14 K = 0.18% Params, 8.87 MMACs = 1.57% MACs, 17.74 MFLOPS = 1.54% FLOPs, 32, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNormAct2d(
#           384 = 0.01% Params, 0 MACs = 0% MACs, 554.5 KFLOPS = 0.05% FLOPs, 192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
# ...
#         )
#         (conv_dw): Conv2d(3.46 K = 0.1% Params, 1.25 MMACs = 0.22% MACs, 2.5 MFLOPS = 0.22% FLOPs, 384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=384, bias=False)
#         (bn2): BatchNormAct2d(
#           768 = 0.02% Params, 0 MACs = 0% MACs, 277.25 KFLOPS = 0.02% FLOPs, 384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs)
#           (act): ReLU6(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs, inplace=True)
#         )
#         (aa): Identity(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs)
#         (se): Identity(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs)
#         (conv_pwl): Conv2d(24.58 K = 0.7% Params, 8.87 MMACs = 1.57% MACs, 17.74 MFLOPS = 1.54% FLOPs, 384, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNormAct2d(
#           128 = 0% Params, 0 MACs = 0% MACs, 46.21 KFLOPS = 0% FLOPs, 64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs)
#           (act): Identity(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs)
#         )
#         (drop_path): Identity(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs)
#       )
#     )
#     (4): Sequential(
#       303.17 K = 8.65% Params, 107.02 MMACs = 18.96% MACs, 216.46 MFLOPS = 18.77% FLOPs
#       (0): InvertedResidual(
#         66.62 K = 1.9% Params, 23.43 MMACs = 4.15% MACs, 47.48 MFLOPS = 4.12% FLOPs
#         (conv_pw): Conv2d(24.58 K = 0.7% Params, 8.87 MMACs = 1.57% MACs, 17.74 MFLOPS = 1.54% FLOPs, 64, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNormAct2d(
#           768 = 0.02% Params, 0 MACs = 0% MACs, 277.25 KFLOPS = 0.02% FLOPs, 384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs)
#           (act): ReLU6(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs, inplace=True)
#         )
#         (conv_dw): Conv2d(3.46 K = 0.1% Params, 1.25 MMACs = 0.22% MACs, 2.5 MFLOPS = 0.22% FLOPs, 384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=384, bias=False)
#         (bn2): BatchNormAct2d(
#           768 = 0.02% Params, 0 MACs = 0% MACs, 277.25 KFLOPS = 0.02% FLOPs, 384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs)
#           (act): ReLU6(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs, inplace=True)
#         )
#         (aa): Identity(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs)
#         (se): Identity(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs)
#         (conv_pwl): Conv2d(36.86 K = 1.05% Params, 13.31 MMACs = 2.36% MACs, 26.62 MFLOPS = 2.31% FLOPs, 384, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNormAct2d(
#           192 = 0.01% Params, 0 MACs = 0% MACs, 69.31 KFLOPS = 0.01% FLOPs, 96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs)
#           (act): Identity(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs)
#         )
#         (drop_path): Identity(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs)
#       )
#       (1): InvertedResidual(
#         118.27 K = 3.37% Params, 41.8 MMACs = 7.41% MACs, 84.49 MFLOPS = 7.33% FLOPs
#         (conv_pw): Conv2d(55.3 K = 1.58% Params, 19.96 MMACs = 3.54% MACs, 39.92 MFLOPS = 3.46% FLOPs, 96, 576, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNormAct2d(
#           1.15 K = 0.03% Params, 0 MACs = 0% MACs, 415.87 KFLOPS = 0.04% FLOPs, 576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs)
#           (act): ReLU6(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs, inplace=True)
#         )
#         (conv_dw): Conv2d(5.18 K = 0.15% Params, 1.87 MMACs = 0.33% MACs, 3.74 MFLOPS = 0.32% FLOPs, 576, 576, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=576, bias=False)
#         (bn2): BatchNormAct2d(
#           1.15 K = 0.03% Params, 0 MACs = 0% MACs, 415.87 KFLOPS = 0.04% FLOPs, 576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs)
#           (act): ReLU6(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs, inplace=True)
#         )
#         (aa): Identity(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs)
#         (se): Identity(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs)
#         (conv_pwl): Conv2d(55.3 K = 1.58% Params, 19.96 MMACs = 3.54% MACs, 39.92 MFLOPS = 3.46% FLOPs, 576, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNormAct2d(
#           192 = 0.01% Params, 0 MACs = 0% MACs, 69.31 KFLOPS = 0.01% FLOPs, 96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs)
#           (act): Identity(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs)
#         )
#         (drop_path): Identity(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs)
#       )
#       (2): InvertedResidual(
#         118.27 K = 3.37% Params, 41.8 MMACs = 7.41% MACs, 84.49 MFLOPS = 7.33% FLOPs
#         (conv_pw): Conv2d(55.3 K = 1.58% Params, 19.96 MMACs = 3.54% MACs, 39.92 MFLOPS = 3.46% FLOPs, 96, 576, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNormAct2d(
#           1.15 K = 0.03% Params, 0 MACs = 0% MACs, 415.87 KFLOPS = 0.04% FLOPs, 576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs)
#           (act): ReLU6(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs, inplace=True)
#         )
#         (conv_dw): Conv2d(5.18 K = 0.15% Params, 1.87 MMACs = 0.33% MACs, 3.74 MFLOPS = 0.32% FLOPs, 576, 576, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=576, bias=False)
#         (bn2): BatchNormAct2d(
#           1.15 K = 0.03% Params, 0 MACs = 0% MACs, 415.87 KFLOPS = 0.04% FLOPs, 576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs)
#           (act): ReLU6(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs, inplace=True)
#         )
#         (aa): Identity(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs)
#         (se): Identity(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs)
#         (conv_pwl): Conv2d(55.3 K = 1.58% Params, 19.96 MMACs = 3.54% MACs, 39.92 MFLOPS = 3.46% FLOPs, 576, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNormAct2d(
#           192 = 0.01% Params, 0 MACs = 0% MACs, 69.31 KFLOPS = 0.01% FLOPs, 96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs)
#           (act): Identity(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs)
#         )
#         (drop_path): Identity(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs)
#       )
#     )
#     (5): Sequential(
#       795.26 K = 22.69% Params, 92.86 MMACs = 16.45% MACs, 187.12 MFLOPS = 16.22% FLOPs
#       (0): InvertedResidual(
#         155.26 K = 4.43% Params, 29.7 MMACs = 5.26% MACs, 59.96 MFLOPS = 5.2% FLOPs
#         (conv_pw): Conv2d(55.3 K = 1.58% Params, 19.96 MMACs = 3.54% MACs, 39.92 MFLOPS = 3.46% FLOPs, 96, 576, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNormAct2d(
#           1.15 K = 0.03% Params, 0 MACs = 0% MACs, 415.87 KFLOPS = 0.04% FLOPs, 576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs)
#           (act): ReLU6(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs, inplace=True)
#         )
#         (conv_dw): Conv2d(5.18 K = 0.15% Params, 518.4 KMACs = 0.09% MACs, 1.04 MFLOPS = 0.09% FLOPs, 576, 576, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=576, bias=False)
#         (bn2): BatchNormAct2d(
#           1.15 K = 0.03% Params, 0 MACs = 0% MACs, 115.2 KFLOPS = 0.01% FLOPs, 576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs)
#           (act): ReLU6(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs, inplace=True)
#         )
#         (aa): Identity(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs)
#         (se): Identity(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs)
#         (conv_pwl): Conv2d(92.16 K = 2.63% Params, 9.22 MMACs = 1.63% MACs, 18.43 MFLOPS = 1.6% FLOPs, 576, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNormAct2d(
#           320 = 0.01% Params, 0 MACs = 0% MACs, 32 KFLOPS = 0% FLOPs, 160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs)
#           (act): Identity(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs)
#         )
#         (drop_path): Identity(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs)
#       )
#       (1): InvertedResidual(
#         320 K = 9.13% Params, 31.58 MMACs = 5.6% MACs, 63.58 MFLOPS = 5.51% FLOPs
#         (conv_pw): Conv2d(153.6 K = 4.38% Params, 15.36 MMACs = 2.72% MACs, 30.72 MFLOPS = 2.66% FLOPs, 160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNormAct2d(
#           1.92 K = 0.05% Params, 0 MACs = 0% MACs, 192 KFLOPS = 0.02% FLOPs, 960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs)
#           (act): ReLU6(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs, inplace=True)
#         )
#         (conv_dw): Conv2d(8.64 K = 0.25% Params, 864 KMACs = 0.15% MACs, 1.73 MFLOPS = 0.15% FLOPs, 960, 960, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=960, bias=False)
#         (bn2): BatchNormAct2d(
#           1.92 K = 0.05% Params, 0 MACs = 0% MACs, 192 KFLOPS = 0.02% FLOPs, 960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs)
#           (act): ReLU6(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs, inplace=True)
#         )
#         (aa): Identity(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs)
#         (se): Identity(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs)
#         (conv_pwl): Conv2d(153.6 K = 4.38% Params, 15.36 MMACs = 2.72% MACs, 30.72 MFLOPS = 2.66% FLOPs, 960, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNormAct2d(
#           320 = 0.01% Params, 0 MACs = 0% MACs, 32 KFLOPS = 0% FLOPs, 160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs)
#           (act): Identity(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs)
#         )
#         (drop_path): Identity(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs)
#       )
#       (2): InvertedResidual(
#         320 K = 9.13% Params, 31.58 MMACs = 5.6% MACs, 63.58 MFLOPS = 5.51% FLOPs
#         (conv_pw): Conv2d(153.6 K = 4.38% Params, 15.36 MMACs = 2.72% MACs, 30.72 MFLOPS = 2.66% FLOPs, 160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNormAct2d(
#           1.92 K = 0.05% Params, 0 MACs = 0% MACs, 192 KFLOPS = 0.02% FLOPs, 960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs)
#           (act): ReLU6(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs, inplace=True)
#         )
#         (conv_dw): Conv2d(8.64 K = 0.25% Params, 864 KMACs = 0.15% MACs, 1.73 MFLOPS = 0.15% FLOPs, 960, 960, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=960, bias=False)
#         (bn2): BatchNormAct2d(
#           1.92 K = 0.05% Params, 0 MACs = 0% MACs, 192 KFLOPS = 0.02% FLOPs, 960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs)
#           (act): ReLU6(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs, inplace=True)
#         )
#         (aa): Identity(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs)
#         (se): Identity(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs)
#         (conv_pwl): Conv2d(153.6 K = 4.38% Params, 15.36 MMACs = 2.72% MACs, 30.72 MFLOPS = 2.66% FLOPs, 960, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNormAct2d(
#           320 = 0.01% Params, 0 MACs = 0% MACs, 32 KFLOPS = 0% FLOPs, 160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs)
#           (act): Identity(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs)
#         )
#         (drop_path): Identity(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs)
#       )
#     )
#     (6): Sequential(
#       473.92 K = 13.52% Params, 46.94 MMACs = 8.32% MACs, 94.34 MFLOPS = 8.18% FLOPs
#       (0): InvertedResidual(
#         473.92 K = 13.52% Params, 46.94 MMACs = 8.32% MACs, 94.34 MFLOPS = 8.18% FLOPs
#         (conv_pw): Conv2d(153.6 K = 4.38% Params, 15.36 MMACs = 2.72% MACs, 30.72 MFLOPS = 2.66% FLOPs, 160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNormAct2d(
#           1.92 K = 0.05% Params, 0 MACs = 0% MACs, 192 KFLOPS = 0.02% FLOPs, 960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs)
#           (act): ReLU6(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs, inplace=True)
#         )
#         (conv_dw): Conv2d(8.64 K = 0.25% Params, 864 KMACs = 0.15% MACs, 1.73 MFLOPS = 0.15% FLOPs, 960, 960, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=960, bias=False)
#         (bn2): BatchNormAct2d(
#           1.92 K = 0.05% Params, 0 MACs = 0% MACs, 192 KFLOPS = 0.02% FLOPs, 960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs)
#           (act): ReLU6(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs, inplace=True)
#         )
#         (aa): Identity(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs)
#         (se): Identity(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs)
#         (conv_pwl): Conv2d(307.2 K = 8.76% Params, 30.72 MMACs = 5.44% MACs, 61.44 MFLOPS = 5.33% FLOPs, 960, 320, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNormAct2d(
#           640 = 0.02% Params, 0 MACs = 0% MACs, 64 KFLOPS = 0.01% FLOPs, 320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs)
#           (act): Identity(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs)
#         )
#         (drop_path): Identity(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs)
#       )
#     )
#   )
#   (conv_head): Conv2d(409.6 K = 11.69% Params, 40.96 MMACs = 7.26% MACs, 81.92 MFLOPS = 7.1% FLOPs, 320, 1280, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (bn2): BatchNormAct2d(
#     2.56 K = 0.07% Params, 0 MACs = 0% MACs, 256 KFLOPS = 0.02% FLOPs, 1280, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#     (drop): Identity(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs)
#     (act): ReLU6(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs, inplace=True)
#   )
#   (global_pool): SelectAdaptivePool2d(pool_type=avg, flatten=Flatten(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs, start_dim=1, end_dim=-1))
#   (classifier): Linear(1.28 M = 36.55% Params, 1.28 MMACs = 0.23% MACs, 2.56 MFLOPS = 0.22% FLOPs, in_features=1280, out_features=1000, bias=True)
# )
# ---------------------------------------------------------------------------------------------------
# +backprop FLOPs: 3.46, MACs: 1.69, MParams: 3.5
# Saved!

# %% [markdown]
# # Measure inference on device
#
# This section allow to measure the inference time on a simulated device using the nn-meter package from Microsoft.

# %% [markdown]
# Use the microsoft's nn-meter to predict latency just to check how good we are with the model.

# %%
# !pip install nn-meter
# Out:
# Collecting nn-meter
#   Downloading nn_meter-2.0-py3-none-any.whl (132 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.5/132.5 kB 2.8 MB/s eta 0:00:00
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from nn-meter) (1.25.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from nn-meter) (2.0.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from nn-meter) (4.66.4)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from nn-meter) (3.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from nn-meter) (2.31.0)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.10/dist-packages (from nn-meter) (3.20.3)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.10/dist-packages (from nn-meter) (6.0.1)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from nn-meter) (1.2.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from nn-meter) (24.1)
# Collecting jsonlines (from nn-meter)
#   Downloading jsonlines-4.0.0-py3-none-any.whl (8.7 kB)
# Requirement already satisfied: attrs>=19.2.0 in /usr/local/lib/python3.10/dist-packages (from jsonlines->nn-meter) (23.2.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->nn-meter) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->nn-meter) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas->nn-meter) (2024.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->nn-meter) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->nn-meter) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->nn-meter) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->nn-meter) (2024.6.2)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->nn-meter) (1.11.4)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->nn-meter) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->nn-meter) (3.5.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas->nn-meter) (1.16.0)
# Installing collected packages: jsonlines, nn-meter
# Successfully installed jsonlines-4.0.0 nn-meter-2.0

# %%
# !nn-meter --list-predictors
# Out:
# (nn-Meter) Supported latency predictors:
# (nn-Meter) [Predictor] cortexA76cpu_tflite21: version=1.0
# (nn-Meter) [Predictor] adreno640gpu_tflite21: version=1.0
# (nn-Meter) [Predictor] adreno630gpu_tflite21: version=1.0
# (nn-Meter) [Predictor] myriadvpu_openvino2019r2: version=1.0

# %%
# save a model as onnx
# !pip install onnx
# !pip install onnxscript
# Out:
# Collecting onnx
#   Downloading onnx-1.16.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (15.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.9/15.9 MB 42.9 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.10/dist-packages (from onnx) (1.25.2)
# Requirement already satisfied: protobuf>=3.20.2 in /usr/local/lib/python3.10/dist-packages (from onnx) (3.20.3)
# Installing collected packages: onnx
# Successfully installed onnx-1.16.1
# Collecting onnxscript
#   Downloading onnxscript-0.1.0.dev20240620-py3-none-any.whl (632 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 632.4/632.4 kB 4.3 MB/s eta 0:00:00
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from onnxscript) (1.25.2)
# Requirement already satisfied: onnx>=1.16 in /usr/local/lib/python3.10/dist-packages (from onnxscript) (1.16.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from onnxscript) (4.12.2)
# Requirement already satisfied: ml-dtypes in /usr/local/lib/python3.10/dist-packages (from onnxscript) (0.2.0)
# Requirement already satisfied: protobuf>=3.20.2 in /usr/local/lib/python3.10/dist-packages (from onnx>=1.16->onnxscript) (3.20.3)
# Installing collected packages: onnxscript
# Successfully installed onnxscript-0.1.0.dev20240620

# %%
import torch.onnx

#Function to Convert to ONNX
def Convert_ONNX(model, input_size):

    # set the model to inference mode
    model.eval()

    # Let's create a dummy input tensor
    dummy_input = torch.randn(*input_size, requires_grad=True)

    # Export the model
    torch.onnx.export(model,         # model being run
         dummy_input,       # model input (or a tuple for multiple inputs)
         "ImageClassifier.onnx",       # where to save the model
         export_params=True,  # store the trained parameter weights inside the model file
         opset_version=10,    # the ONNX version to export the model to
         do_constant_folding=True,  # whether to execute constant folding for optimization
         input_names = ['modelInput'],   # the model's input names
         output_names = ['modelOutput'], # the model's output names
         dynamic_axes={'modelInput' : {0 : 'batch_size'},    # variable length axes
                                'modelOutput' : {0 : 'batch_size'}})
    print(" ")
    print('Model has been converted to ONNX')

# %%
import torch
#onnx_program = torch.onnx.dynamo_export(model, input_shape)
print(input_shape)
Convert_ONNX(model, input_shape)
# Out:
# (1, 3, 224, 224)
# /usr/local/lib/python3.10/dist-packages/calflops/pytorch_ops.py:84: TracerWarning: Converting a tensor to a Python boolean might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
#   assert weight.shape[1] * groups == input.shape[1]
# /usr/local/lib/python3.10/dist-packages/calflops/pytorch_ops.py:116: TracerWarning: Converting a tensor to a Python integer might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
#   conv_per_position_macs = int(_prod(kernel_dims)) * in_channels * filters_per_channel
# /usr/local/lib/python3.10/dist-packages/calflops/pytorch_ops.py:117: TracerWarning: Converting a tensor to a Python integer might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
#   active_elements_count = batch_size * int(_prod(output_dims))
# /usr/local/lib/python3.10/dist-packages/calflops/pytorch_ops.py:125: TracerWarning: Converting a tensor to a Python integer might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
#   return int(overall_conv_flops + bias_flops), int(overall_conv_macs)
# /usr/local/lib/python3.10/dist-packages/calflops/pytorch_ops.py:362: TracerWarning: Converting a tensor to a Python boolean might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
#   if module_mac_count and macs:
#
# Model has been converted to ONNX

# %% [markdown]
# Try out the onnx model

# %%
# !nn-meter predict --predictor cortexA76cpu_tflite21 --predictor-version 1.0 --onnx ImageClassifier.onnx
# Out:
# (nn-Meter) checking local kernel predictors at /root/.nn_meter/data/predictor/cortexA76cpu_tflite21
# (nn-Meter) Download from https://github.com/microsoft/nn-Meter/releases/download/v1.0-data/cortexA76cpu_tflite21.zip ...
# 100% 376M/376M [00:17<00:00, 21.4MiB/s]
# (nn-Meter) load predictor /root/.nn_meter/data/predictor/cortexA76cpu_tflite21/se.pkl
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:318: UserWarning: Trying to unpickle estimator DecisionTreeRegressor from version 0.23.1 when using version 1.2.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:318: UserWarning: Trying to unpickle estimator RandomForestRegressor from version 0.23.1 when using version 1.2.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# (nn-Meter) load predictor /root/.nn_meter/data/predictor/cortexA76cpu_tflite21/conv-bn-relu.pkl
# (nn-Meter) load predictor /root/.nn_meter/data/predictor/cortexA76cpu_tflite21/add.pkl
# (nn-Meter) load predictor /root/.nn_meter/data/predictor/cortexA76cpu_tflite21/avgpool.pkl
# (nn-Meter) load predictor /root/.nn_meter/data/predictor/cortexA76cpu_tflite21/addrelu.pkl
# (nn-Meter) load predictor /root/.nn_meter/data/predictor/cortexA76cpu_tflite21/channelshuffle.pkl
# (nn-Meter) load predictor /root/.nn_meter/data/predictor/cortexA76cpu_tflite21/hswish.pkl
# (nn-Meter) load predictor /root/.nn_meter/data/predictor/cortexA76cpu_tflite21/global-avgpool.pkl
# (nn-Meter) load predictor /root/.nn_meter/data/predictor/cortexA76cpu_tflite21/concat.pkl
# (nn-Meter) load predictor /root/.nn_meter/data/predictor/cortexA76cpu_tflite21/bn.pkl
# (nn-Meter) load predictor /root/.nn_meter/data/predictor/cortexA76cpu_tflite21/relu.pkl
# (nn-Meter) load predictor /root/.nn_meter/data/predictor/cortexA76cpu_tflite21/split.pkl
# (nn-Meter) load predictor /root/.nn_meter/data/predictor/cortexA76cpu_tflite21/fc.pkl
# (nn-Meter) load predictor /root/.nn_meter/data/predictor/cortexA76cpu_tflite21/bnrelu.pkl
# (nn-Meter) load predictor /root/.nn_meter/data/predictor/cortexA76cpu_tflite21/maxpool.pkl
# (nn-Meter) load predictor /root/.nn_meter/data/predictor/cortexA76cpu_tflite21/dwconv-bn-relu.pkl
# (nn-Meter) Start latency prediction ...
# (nn-Meter) onnx==1.16.1 is not well tested now, well tested version: onnx==1.10.0, 1.9.0
# (nn-Meter) onnx==1.16.1 is not well tested now, well tested version: onnx==1.10.0, 1.9.0
# (nn-Meter) Predict latency: 56.408001179298594 ms
# (nn-Meter) [RESULT] predict latency for ImageClassifier.onnx: 56.408001179298594 ms

# %% [markdown]
# # Inference benchmark in PyTorch
#
# A simple inference benchmark to measure the prediction speed on CPU in pure PyTorch.
#
# https://medium.com/@sgurwinderr/pytorch-model-benchmarking-obtaining-accurate-results-by-accounting-for-warmup-5cc40ed59a34

# %%
import time
import torch

num_inference = 100
total_inference_time = 0
input_data = torch.randn(*input_shape)  # Replace with your input data
#input_data=input_data.to("xpu") # Using Intel GPU

#model=model.to("xpu") # Using Intel GPU
#model = ipex.optimize(model) # Using Intel GPU
model.eval()

for i in range(3):  # Perform 3 warmup iterations
    with torch.no_grad():
        _ = model(input_data)

for _ in range(num_inference):
    with torch.no_grad():
        start_time = time.time()
        expected_output = model(input_data)
        end_time = time.time()
    inference_time = end_time - start_time
    total_inference_time += inference_time

average_inference_time = total_inference_time / num_inference
print(average_inference_time * 1000, 'ms')

avg_inf_time_ms = round(average_inference_time*1000,2)
log.add(model_name, input_shape[-1], inference_ms=avg_inf_time_ms)
# Out:
# 24.048349857330322 ms
# Saved!

# %% [markdown]
# # Train time benchmark
#
# Benchmark a simple back propagation (make dummy data).
#
# Due to the issues with the sizes and times use the Collab's L4 as a GPU reference.

# %%
import torch
import time

def execute_train(model, data, labels, epochs):
  device = "cuda" if torch.cuda.is_available() else "cpu"
  if device == "cpu":
    raise "No GPU for training."

  # move stuff to GPU
  model = model.to(device)
  data, labels = data.to(device), labels.to(device)

  optimizer = torch.optim.SGD(model.parameters(), lr=0.01)
  loss_function = torch.nn.CrossEntropyLoss()

  for i in range(5):  # Perform 3 warmup iterations
    # Forward pass
    outputs = model(data)
    # Calculate the loss
    loss = loss_function(outputs, labels)
    # Backward pass
    optimizer.zero_grad()
    loss.backward()
    # Update the parameters
    optimizer.step()

  total_train_time = 0
  for _ in range(epochs):
    start_time = time.time()

    # Forward pass
    outputs = model(data)
    # Calculate the loss
    loss = loss_function(outputs, labels)
    # Backward pass
    optimizer.zero_grad()
    loss.backward()
    # Update the parameters
    optimizer.step()

    end_time = time.time()
    train_time = end_time - start_time
    #print(train_time)
    total_train_time += train_time
  return total_train_time / epochs

# %%
epochs = 10

batch_size = 32
model, shape = getModel(model_name, input_image_size)
input_shape = (batch_size, *shape)
input_data = torch.randn(*input_shape)  # Replace with your input data
labels = torch.randint(0,999, (batch_size,))    # Replace with your labels

model.train()

#print(input_data.shape)
#print(labels.shape)
avg_train_time = execute_train(model, input_data, labels, epochs)
bps = round(1/avg_train_time,2)
print(f"Batches per second: {bps}")

log.add(model_name, input_shape[-1], train_b32ps=bps)
# Out:
# Batches per second: 7.56
# Saved!
